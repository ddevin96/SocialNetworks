# %%
using Pkg
Pkg.add("CSV")
Pkg.add("DataFrames")
Pkg.add("Plots")
using CSV
using DataFrames
using Plots
# Out:
#    Resolving package versions...
#   No Changes to `~/Documents/vscode/SocialNetworks/Project.toml`
#   No Changes to `~/Documents/vscode/SocialNetworks/Manifest.toml`
#    Resolving package versions...
#   No Changes to `~/Documents/vscode/SocialNetworks/Project.toml`
#   No Changes to `~/Documents/vscode/SocialNetworks/Manifest.toml`
#    Resolving package versions...
#   No Changes to `~/Documents/vscode/SocialNetworks/Project.toml`
#   No Changes to `~/Documents/vscode/SocialNetworks/Manifest.toml`

# %%
# DataFrame(CSV.File("../../results/mts/ca-GrQc.edges.txt"))

# read all content in a folder
df = DataFrame()
for dir in readdir("../../results")
    println(dir)
    for file in readdir("../../results/$dir")
        # if file ends with .txt
        if !occursin(".txt", file)
            continue
        end

        df_temp= DataFrame(CSV.File("../../results/$dir/$file"))
        # add df_temp to df
        df = vcat(df, df_temp)
    end
end
a = ["Algorithm", "Graph", "l", "th", "avg"]
rename!(df, names(df) .=> a)
println(df)

graphs = ["karate", "ca-GrQc", "ca-HepTh", "CollegeMsg", "email-EU-core", "facebook", "p2p"]
# Out:
# deg
# maxdeg
# mts
# rand
# 448×5 DataFrame
#  Row │ Algorithm  Graph          l        th       avg
#      │ String7    String15       Float64  Float64  Float64
# ─────┼─────────────────────────────────────────────────────
#    1 │ DEG        CollegeMsg      473.5      0.25      9.0
#    2 │ DEG        CollegeMsg      473.5      0.5      35.0
#    3 │ DEG        CollegeMsg      473.5      0.75    109.0
#    4 │ DEG        CollegeMsg      473.5      1.0       3.0
#    5 │ DEG        CollegeMsg      947.0      0.25      9.0
#    6 │ DEG        CollegeMsg      947.0      0.5      64.0
#    7 │ DEG        CollegeMsg      947.0      0.75    221.0
#    8 │ DEG        CollegeMsg      947.0      1.0       2.0
#    9 │ DEG        CollegeMsg     1420.5      0.25      9.0
#   10 │ DEG        CollegeMsg     1420.5      0.5      64.0
#   11 │ DEG        CollegeMsg     1420.5      0.75    257.0
#   12 │ DEG        CollegeMsg     1420.5      1.0      39.0
#   13 │ DEG        CollegeMsg     1894.0      0.25   1801.0
#   14 │ DEG        CollegeMsg     1894.0      0.5    1801.0
#   15 │ DEG        CollegeMsg     1894.0      0.75   1801.0
#   16 │ DEG        CollegeMsg     1894.0      1.0    1801.0
#   17 │ DEG        ca-GrQc        1310.5      0.25      3.0
#   18 │ DEG        ca-GrQc        1310.5      0.5     367.0
#   19 │ DEG        ca-GrQc        1310.5      0.75    708.0
#   20 │ DEG        ca-GrQc        1310.5      1.0     253.0
#   21 │ DEG        ca-GrQc        2621.0      0.25      3.0
#   22 │ DEG        ca-GrQc        2621.0      0.5     614.0
#   23 │ DEG        ca-GrQc        2621.0      0.75   1390.0
#   24 │ DEG        ca-GrQc        2621.0      1.0     632.0
#   25 │ DEG        ca-GrQc        3931.5      0.25    371.0
#   26 │ DEG        ca-GrQc        3931.5      0.5    1582.0
#   27 │ DEG        ca-GrQc        3931.5      0.75   2639.0
#   28 │ DEG        ca-GrQc        3931.5      1.0    1768.0
#   29 │ DEG        ca-GrQc        5242.0      0.25   5086.0
#   30 │ DEG        ca-GrQc        5242.0      0.5    5086.0
#   31 │ DEG        ca-GrQc        5242.0      0.75   5086.0
#   32 │ DEG        ca-GrQc        5242.0      1.0    5086.0
#   33 │ DEG        ca-HepTh       2469.25     0.25      8.0
#   34 │ DEG        ca-HepTh       2469.25     0.5     343.0
#   35 │ DEG        ca-HepTh       2469.25     0.75   1155.0
#   36 │ DEG        ca-HepTh       2469.25     1.0     194.0
#   37 │ DEG        ca-HepTh       4938.5      0.25      8.0
#   38 │ DEG        ca-HepTh       4938.5      0.5     656.0
#   39 │ DEG        ca-HepTh       4938.5      0.75   2314.0
#   40 │ DEG        ca-HepTh       4938.5      1.0     794.0
#   41 │ DEG        ca-HepTh       7407.75     0.25      8.0
#   42 │ DEG        ca-HepTh       7407.75     0.5    2002.0
#   43 │ DEG        ca-HepTh       7407.75     0.75   4580.0
#   44 │ DEG        ca-HepTh       7407.75     1.0    2671.0
#   45 │ DEG        ca-HepTh       9877.0      0.25   9771.0
#   46 │ DEG        ca-HepTh       9877.0      0.5    9771.0
#   47 │ DEG        ca-HepTh       9877.0      0.75   9771.0
#   48 │ DEG        ca-HepTh       9877.0      1.0    9771.0
#   49 │ DEG        email-EU-core   251.25     0.25     14.0
#   50 │ DEG        email-EU-core   251.25     0.5      56.0
#   51 │ DEG        email-EU-core   251.25     0.75    149.0
#   52 │ DEG        email-EU-core   251.25     1.0       1.0
#   53 │ DEG        email-EU-core   502.5      0.25     14.0
#   54 │ DEG        email-EU-core   502.5      0.5      56.0
#   55 │ DEG        email-EU-core   502.5      0.75    234.0
#   56 │ DEG        email-EU-core   502.5      1.0      11.0
#   57 │ DEG        email-EU-core   753.75     0.25     14.0
#   58 │ DEG        email-EU-core   753.75     0.5      56.0
#   59 │ DEG        email-EU-core   753.75     0.75    276.0
#   60 │ DEG        email-EU-core   753.75     1.0      45.0
#   61 │ DEG        email-EU-core  1005.0      0.25    996.0
#   62 │ DEG        email-EU-core  1005.0      0.5     996.0
#   63 │ DEG        email-EU-core  1005.0      0.75    996.0
#   64 │ DEG        email-EU-core  1005.0      1.0     996.0
#   65 │ DEG        facebook         83.25     0.25      5.0
#   66 │ DEG        facebook         83.25     0.5      17.0
#   67 │ DEG        facebook         83.25     0.75     46.0
#   68 │ DEG        facebook         83.25     1.0       6.0
#   69 │ DEG        facebook        166.5      0.25      5.0
#   70 │ DEG        facebook        166.5      0.5      17.0
#   71 │ DEG        facebook        166.5      0.75     84.0
#   72 │ DEG        facebook        166.5      1.0      45.0
#   73 │ DEG        facebook        249.75     0.25     56.0
#   74 │ DEG        facebook        249.75     0.5     111.0
#   75 │ DEG        facebook        249.75     0.75    198.0
#   76 │ DEG        facebook        249.75     1.0     120.0
#   77 │ DEG        facebook        333.0      0.25    317.0
#   78 │ DEG        facebook        333.0      0.5     317.0
#   79 │ DEG        facebook        333.0      0.75    317.0
#   80 │ DEG        facebook        333.0      1.0     317.0
#   81 │ DEG        karate            8.5      0.25      1.0
#   82 │ DEG        karate            8.5      0.5       1.0
#   83 │ DEG        karate            8.5      0.75      3.0
#   84 │ DEG        karate            8.5      1.0       1.0
#   85 │ DEG        karate           17.0      0.25      1.0
#   86 │ DEG        karate           17.0      0.5       2.0
#   87 │ DEG        karate           17.0      0.75      5.0
#   88 │ DEG        karate           17.0      1.0       2.0
#   89 │ DEG        karate           25.5      0.25      1.0
#   90 │ DEG        karate           25.5      0.5       2.0
#   91 │ DEG        karate           25.5      0.75      8.0
#   92 │ DEG        karate           25.5      1.0       1.0
#   93 │ DEG        karate           34.0      0.25      1.0
#   94 │ DEG        karate           34.0      0.5      10.0
#   95 │ DEG        karate           34.0      0.75     17.0
#   96 │ DEG        karate           34.0      1.0       7.0
#   97 │ DEG        p2p            1575.25     0.25      9.0
#   98 │ DEG        p2p            1575.25     0.5     351.0
#   99 │ DEG        p2p            1575.25     0.75    645.0
#  100 │ DEG        p2p            1575.25     1.0      67.0
#  101 │ DEG        p2p            3150.5      0.25      9.0
#  102 │ DEG        p2p            3150.5      0.5     490.0
#  103 │ DEG        p2p            3150.5      0.75   1322.0
#  104 │ DEG        p2p            3150.5      1.0     208.0
#  105 │ DEG        p2p            4725.75     0.25      9.0
#  106 │ DEG        p2p            4725.75     0.5     490.0
#  107 │ DEG        p2p            4725.75     0.75   1742.0
#  108 │ DEG        p2p            4725.75     1.0     918.0
#  109 │ DEG        p2p            6301.0      0.25   5537.0
#  110 │ DEG        p2p            6301.0      0.5    5537.0
#  111 │ DEG        p2p            6301.0      0.75   5537.0
#  112 │ DEG        p2p            6301.0      1.0    5537.0
#  113 │ MAX DEG    CollegeMsg      473.5      0.25      9.0
#  114 │ MAX DEG    CollegeMsg      473.5      0.5      36.0
#  115 │ MAX DEG    CollegeMsg      473.5      0.75    100.0
#  116 │ MAX DEG    CollegeMsg      473.5      1.0       1.0
#  117 │ MAX DEG    CollegeMsg      947.0      0.25     10.0
#  118 │ MAX DEG    CollegeMsg      947.0      0.5      66.0
#  119 │ MAX DEG    CollegeMsg      947.0      0.75    207.0
#  120 │ MAX DEG    CollegeMsg      947.0      1.0       5.0
#  121 │ MAX DEG    CollegeMsg     1420.5      0.25     10.0
#  122 │ MAX DEG    CollegeMsg     1420.5      0.5      66.0
#  123 │ MAX DEG    CollegeMsg     1420.5      0.75    219.0
#  124 │ MAX DEG    CollegeMsg     1420.5      1.0      10.0
#  125 │ MAX DEG    CollegeMsg     1894.0      0.25     13.0
#  126 │ MAX DEG    CollegeMsg     1894.0      0.5      69.0
#  127 │ MAX DEG    CollegeMsg     1894.0      0.75    259.0
#  128 │ MAX DEG    CollegeMsg     1894.0      1.0      63.0
#  129 │ MAX DEG    ca-GrQc        1310.5      0.25      4.0
#  130 │ MAX DEG    ca-GrQc        1310.5      0.5     223.0
#  131 │ MAX DEG    ca-GrQc        1310.5      0.75    636.0
#  132 │ MAX DEG    ca-GrQc        1310.5      1.0      65.0
#  133 │ MAX DEG    ca-GrQc        2621.0      0.25      4.0
#  134 │ MAX DEG    ca-GrQc        2621.0      0.5     321.0
#  135 │ MAX DEG    ca-GrQc        2621.0      0.75   1141.0
#  136 │ MAX DEG    ca-GrQc        2621.0      1.0     245.0
#  137 │ MAX DEG    ca-GrQc        3931.5      0.25     36.0
#  138 │ MAX DEG    ca-GrQc        3931.5      0.5     514.0
#  139 │ MAX DEG    ca-GrQc        3931.5      0.75   1654.0
#  140 │ MAX DEG    ca-GrQc        3931.5      1.0     527.0
#  141 │ MAX DEG    ca-GrQc        5242.0      0.25    421.0
#  142 │ MAX DEG    ca-GrQc        5242.0      0.5     969.0
#  143 │ MAX DEG    ca-GrQc        5242.0      0.75   2310.0
#  144 │ MAX DEG    ca-GrQc        5242.0      1.0    1097.0
#  145 │ MAX DEG    ca-HepTh       2469.25     0.25      9.0
#  146 │ MAX DEG    ca-HepTh       2469.25     0.5     262.0
#  147 │ MAX DEG    ca-HepTh       2469.25     0.75   1146.0
#  148 │ MAX DEG    ca-HepTh       2469.25     1.0     103.0
#  149 │ MAX DEG    ca-HepTh       4938.5      0.25      9.0
#  150 │ MAX DEG    ca-HepTh       4938.5      0.5     374.0
#  151 │ MAX DEG    ca-HepTh       4938.5      0.75   1881.0
#  152 │ MAX DEG    ca-HepTh       4938.5      1.0     319.0
#  153 │ MAX DEG    ca-HepTh       7407.75     0.25      9.0
#  154 │ MAX DEG    ca-HepTh       7407.75     0.5     562.0
#  155 │ MAX DEG    ca-HepTh       7407.75     0.75   2756.0
#  156 │ MAX DEG    ca-HepTh       7407.75     1.0     806.0
#  157 │ MAX DEG    ca-HepTh       9877.0      0.25    475.0
#  158 │ MAX DEG    ca-HepTh       9877.0      0.5    1286.0
#  159 │ MAX DEG    ca-HepTh       9877.0      0.75   3927.0
#  160 │ MAX DEG    ca-HepTh       9877.0      1.0    1842.0
#  161 │ MAX DEG    email-EU-core   251.25     0.25     14.0
#  162 │ MAX DEG    email-EU-core   251.25     0.5      61.0
#  163 │ MAX DEG    email-EU-core   251.25     0.75    150.0
#  164 │ MAX DEG    email-EU-core   251.25     1.0       6.0
#  165 │ MAX DEG    email-EU-core   502.5      0.25     14.0
#  166 │ MAX DEG    email-EU-core   502.5      0.5      61.0
#  167 │ MAX DEG    email-EU-core   502.5      0.75    219.0
#  168 │ MAX DEG    email-EU-core   502.5      1.0      12.0
#  169 │ MAX DEG    email-EU-core   753.75     0.25     14.0
#  170 │ MAX DEG    email-EU-core   753.75     0.5      61.0
#  171 │ MAX DEG    email-EU-core   753.75     0.75    223.0
#  172 │ MAX DEG    email-EU-core   753.75     1.0      10.0
#  173 │ MAX DEG    email-EU-core  1005.0      0.25     33.0
#  174 │ MAX DEG    email-EU-core  1005.0      0.5      80.0
#  175 │ MAX DEG    email-EU-core  1005.0      0.75    288.0
#  176 │ MAX DEG    email-EU-core  1005.0      1.0     103.0
#  177 │ MAX DEG    facebook         83.25     0.25      5.0
#  178 │ MAX DEG    facebook         83.25     0.5      17.0
#  179 │ MAX DEG    facebook         83.25     0.75     51.0
#  180 │ MAX DEG    facebook         83.25     1.0       7.0
#  181 │ MAX DEG    facebook        166.5      0.25      5.0
#  182 │ MAX DEG    facebook        166.5      0.5      17.0
#  183 │ MAX DEG    facebook        166.5      0.75     72.0
#  184 │ MAX DEG    facebook        166.5      1.0      15.0
#  185 │ MAX DEG    facebook        249.75     0.25      6.0
#  186 │ MAX DEG    facebook        249.75     0.5      31.0
#  187 │ MAX DEG    facebook        249.75     0.75     94.0
#  188 │ MAX DEG    facebook        249.75     1.0      23.0
#  189 │ MAX DEG    facebook        333.0      0.25     15.0
#  190 │ MAX DEG    facebook        333.0      0.5      49.0
#  191 │ MAX DEG    facebook        333.0      0.75    123.0
#  192 │ MAX DEG    facebook        333.0      1.0      48.0
#  193 │ MAX DEG    karate            8.5      0.25      1.0
#  194 │ MAX DEG    karate            8.5      0.5       1.0
#  195 │ MAX DEG    karate            8.5      0.75      3.0
#  196 │ MAX DEG    karate            8.5      1.0       3.0
#  197 │ MAX DEG    karate           17.0      0.25      1.0
#  198 │ MAX DEG    karate           17.0      0.5       2.0
#  199 │ MAX DEG    karate           17.0      0.75      5.0
#  200 │ MAX DEG    karate           17.0      1.0       3.0
#  201 │ MAX DEG    karate           25.5      0.25      1.0
#  202 │ MAX DEG    karate           25.5      0.5       2.0
#  203 │ MAX DEG    karate           25.5      0.75      7.0
#  204 │ MAX DEG    karate           25.5      1.0       1.0
#  205 │ MAX DEG    karate           34.0      0.25      1.0
#  206 │ MAX DEG    karate           34.0      0.5       3.0
#  207 │ MAX DEG    karate           34.0      0.75     10.0
#  208 │ MAX DEG    karate           34.0      1.0       4.0
#  209 │ MAX DEG    p2p            1575.25     0.25     10.0
#  210 │ MAX DEG    p2p            1575.25     0.5     258.0
#  211 │ MAX DEG    p2p            1575.25     0.75    547.0
#  212 │ MAX DEG    p2p            1575.25     1.0      20.0
#  213 │ MAX DEG    p2p            3150.5      0.25     10.0
#  214 │ MAX DEG    p2p            3150.5      0.5     356.0
#  215 │ MAX DEG    p2p            3150.5      0.75    960.0
#  216 │ MAX DEG    p2p            3150.5      1.0     156.0
#  217 │ MAX DEG    p2p            4725.75     0.25     10.0
#  218 │ MAX DEG    p2p            4725.75     0.5     356.0
#  219 │ MAX DEG    p2p            4725.75     0.75   1233.0
#  220 │ MAX DEG    p2p            4725.75     1.0     304.0
#  221 │ MAX DEG    p2p            6301.0      0.25     14.0
#  222 │ MAX DEG    p2p            6301.0      0.5     361.0
#  223 │ MAX DEG    p2p            6301.0      0.75   1536.0
#  224 │ MAX DEG    p2p            6301.0      1.0     607.0
#  225 │ MTS        CollegeMsg      473.5      0.25    339.2
#  226 │ MTS        CollegeMsg      473.5      0.5     264.2
#  227 │ MTS        CollegeMsg      473.5      0.75    229.4
#  228 │ MTS        CollegeMsg      473.5      1.0       8.3
#  229 │ MTS        CollegeMsg      947.0      0.25    385.1
#  230 │ MTS        CollegeMsg      947.0      0.5     429.1
#  231 │ MTS        CollegeMsg      947.0      0.75    422.3
#  232 │ MTS        CollegeMsg      947.0      1.0      59.8
#  233 │ MTS        CollegeMsg     1420.5      0.25    392.7
#  234 │ MTS        CollegeMsg     1420.5      0.5     484.9
#  235 │ MTS        CollegeMsg     1420.5      0.75    602.3
#  236 │ MTS        CollegeMsg     1420.5      1.0      41.1
#  237 │ MTS        CollegeMsg     1894.0      0.25    387.8
#  238 │ MTS        CollegeMsg     1894.0      0.5     485.6
#  239 │ MTS        CollegeMsg     1894.0      0.75    649.9
#  240 │ MTS        CollegeMsg     1894.0      1.0     105.2
#  241 │ MTS        ca-GrQc        1310.5      0.25    419.2
#  242 │ MTS        ca-GrQc        1310.5      0.5     621.7
#  243 │ MTS        ca-GrQc        1310.5      0.75    630.2
#  244 │ MTS        ca-GrQc        1310.5      1.0     422.7
#  245 │ MTS        ca-GrQc        2621.0      0.25    414.0
#  246 │ MTS        ca-GrQc        2621.0      0.5    1101.0
#  247 │ MTS        ca-GrQc        2621.0      0.75   1391.8
#  248 │ MTS        ca-GrQc        2621.0      1.0     683.8
#  249 │ MTS        ca-GrQc        3931.5      0.25    403.9
#  250 │ MTS        ca-GrQc        3931.5      0.5    1458.2
#  251 │ MTS        ca-GrQc        3931.5      0.75   2067.6
#  252 │ MTS        ca-GrQc        3931.5      1.0    1040.0
#  253 │ MTS        ca-GrQc        5242.0      0.25    610.2
#  254 │ MTS        ca-GrQc        5242.0      0.5    1816.0
#  255 │ MTS        ca-GrQc        5242.0      0.75   2768.7
#  256 │ MTS        ca-GrQc        5242.0      1.0    1239.3
#  257 │ MTS        ca-HepTh       2469.25     0.25    712.8
#  258 │ MTS        ca-HepTh       2469.25     0.5    1121.6
#  259 │ MTS        ca-HepTh       2469.25     0.75   1279.1
#  260 │ MTS        ca-HepTh       2469.25     1.0     639.3
#  261 │ MTS        ca-HepTh       4938.5      0.25    713.1
#  262 │ MTS        ca-HepTh       4938.5      0.5    2131.2
#  263 │ MTS        ca-HepTh       4938.5      0.75   2716.4
#  264 │ MTS        ca-HepTh       4938.5      1.0    1137.5
#  265 │ MTS        ca-HepTh       7407.75     0.25    714.1
#  266 │ MTS        ca-HepTh       7407.75     0.5    2842.5
#  267 │ MTS        ca-HepTh       7407.75     0.75   3963.6
#  268 │ MTS        ca-HepTh       7407.75     1.0    1595.2
#  269 │ MTS        ca-HepTh       9877.0      0.25    858.2
#  270 │ MTS        ca-HepTh       9877.0      0.5    3105.3
#  271 │ MTS        ca-HepTh       9877.0      0.75   4994.8
#  272 │ MTS        ca-HepTh       9877.0      1.0    2031.8
#  273 │ MTS        email-EU-core   251.25     0.25    144.0
#  274 │ MTS        email-EU-core   251.25     0.5     218.9
#  275 │ MTS        email-EU-core   251.25     0.75    223.4
#  276 │ MTS        email-EU-core   251.25     1.0      61.1
#  277 │ MTS        email-EU-core   502.5      0.25    144.0
#  278 │ MTS        email-EU-core   502.5      0.5     353.8
#  279 │ MTS        email-EU-core   502.5      0.75    415.3
#  280 │ MTS        email-EU-core   502.5      1.0      70.9
#  281 │ MTS        email-EU-core   753.75     0.25    144.0
#  282 │ MTS        email-EU-core   753.75     0.5     428.5
#  283 │ MTS        email-EU-core   753.75     0.75    544.8
#  284 │ MTS        email-EU-core   753.75     1.0      67.8
#  285 │ MTS        email-EU-core  1005.0      0.25    144.0
#  286 │ MTS        email-EU-core  1005.0      0.5     428.6
#  287 │ MTS        email-EU-core  1005.0      0.75    579.9
#  288 │ MTS        email-EU-core  1005.0      1.0     152.3
#  289 │ MTS        facebook         83.25     0.25     21.5
#  290 │ MTS        facebook         83.25     0.5      39.3
#  291 │ MTS        facebook         83.25     0.75     50.6
#  292 │ MTS        facebook         83.25     1.0      21.8
#  293 │ MTS        facebook        166.5      0.25     43.3
#  294 │ MTS        facebook        166.5      0.5      87.9
#  295 │ MTS        facebook        166.5      0.75    107.7
#  296 │ MTS        facebook        166.5      1.0      29.3
#  297 │ MTS        facebook        249.75     0.25     45.0
#  298 │ MTS        facebook        249.75     0.5     125.9
#  299 │ MTS        facebook        249.75     0.75    161.4
#  300 │ MTS        facebook        249.75     1.0      54.5
#  301 │ MTS        facebook        333.0      0.25     46.2
#  302 │ MTS        facebook        333.0      0.5     125.1
#  303 │ MTS        facebook        333.0      0.75    182.4
#  304 │ MTS        facebook        333.0      1.0      61.2
#  305 │ MTS        karate            8.5      0.25      1.0
#  306 │ MTS        karate            8.5      0.5       3.0
#  307 │ MTS        karate            8.5      0.75      5.3
#  308 │ MTS        karate            8.5      1.0       1.0
#  309 │ MTS        karate           17.0      0.25      1.0
#  310 │ MTS        karate           17.0      0.5       3.0
#  311 │ MTS        karate           17.0      0.75      7.3
#  312 │ MTS        karate           17.0      1.0       2.0
#  313 │ MTS        karate           25.5      0.25      1.0
#  314 │ MTS        karate           25.5      0.5       5.0
#  315 │ MTS        karate           25.5      0.75     11.9
#  316 │ MTS        karate           25.5      1.0       2.6
#  317 │ MTS        karate           34.0      0.25      1.0
#  318 │ MTS        karate           34.0      0.5       5.0
#  319 │ MTS        karate           34.0      0.75     12.1
#  320 │ MTS        karate           34.0      1.0       4.5
#  321 │ MTS        p2p            1575.25     0.25    479.7
#  322 │ MTS        p2p            1575.25     0.5     931.9
#  323 │ MTS        p2p            1575.25     0.75    512.5
#  324 │ MTS        p2p            1575.25     1.0     175.9
#  325 │ MTS        p2p            3150.5      0.25    466.6
#  326 │ MTS        p2p            3150.5      0.5    1649.8
#  327 │ MTS        p2p            3150.5      0.75   1114.8
#  328 │ MTS        p2p            3150.5      1.0     279.8
#  329 │ MTS        p2p            4725.75     0.25    469.3
#  330 │ MTS        p2p            4725.75     0.5    1815.9
#  331 │ MTS        p2p            4725.75     0.75   1740.8
#  332 │ MTS        p2p            4725.75     1.0     415.0
#  333 │ MTS        p2p            6301.0      0.25    467.4
#  334 │ MTS        p2p            6301.0      0.5    1869.5
#  335 │ MTS        p2p            6301.0      0.75   2197.3
#  336 │ MTS        p2p            6301.0      1.0     633.5
#  337 │ RANDOM     CollegeMsg      473.5      0.25    168.2
#  338 │ RANDOM     CollegeMsg      473.5      0.5     320.0
#  339 │ RANDOM     CollegeMsg      473.5      0.75    393.3
#  340 │ RANDOM     CollegeMsg      473.5      1.0      55.7
#  341 │ RANDOM     CollegeMsg      947.0      0.25    182.1
#  342 │ RANDOM     CollegeMsg      947.0      0.5     603.9
#  343 │ RANDOM     CollegeMsg      947.0      0.75    797.2
#  344 │ RANDOM     CollegeMsg      947.0      1.0     145.9
#  345 │ RANDOM     CollegeMsg     1420.5      0.25    164.9
#  346 │ RANDOM     CollegeMsg     1420.5      0.5     631.9
#  347 │ RANDOM     CollegeMsg     1420.5      0.75   1187.6
#  348 │ RANDOM     CollegeMsg     1420.5      1.0     317.6
#  349 │ RANDOM     CollegeMsg     1894.0      0.25   1254.9
#  350 │ RANDOM     CollegeMsg     1894.0      0.5    1125.7
#  351 │ RANDOM     CollegeMsg     1894.0      0.75   1579.8
#  352 │ RANDOM     CollegeMsg     1894.0      1.0    1609.3
#  353 │ RANDOM     ca-GrQc        1310.5      0.25     45.2
#  354 │ RANDOM     ca-GrQc        1310.5      0.5     686.6
#  355 │ RANDOM     ca-GrQc        1310.5      0.75   1052.2
#  356 │ RANDOM     ca-GrQc        1310.5      1.0     324.8
#  357 │ RANDOM     ca-GrQc        2621.0      0.25     30.3
#  358 │ RANDOM     ca-GrQc        2621.0      0.5    1193.0
#  359 │ RANDOM     ca-GrQc        2621.0      0.75   2088.4
#  360 │ RANDOM     ca-GrQc        2621.0      1.0     869.4
#  361 │ RANDOM     ca-GrQc        3931.5      0.25    216.1
#  362 │ RANDOM     ca-GrQc        3931.5      0.5    1469.6
#  363 │ RANDOM     ca-GrQc        3931.5      0.75   3084.8
#  364 │ RANDOM     ca-GrQc        3931.5      1.0    1643.8
#  365 │ RANDOM     ca-GrQc        5242.0      0.25   4952.5
#  366 │ RANDOM     ca-GrQc        5242.0      0.5    4849.3
#  367 │ RANDOM     ca-GrQc        5242.0      0.75   5093.4
#  368 │ RANDOM     ca-GrQc        5242.0      1.0    5041.2
#  369 │ RANDOM     ca-HepTh       2469.25     0.25     85.3
#  370 │ RANDOM     ca-HepTh       2469.25     0.5    1325.3
#  371 │ RANDOM     ca-HepTh       2469.25     0.75   2012.5
#  372 │ RANDOM     ca-HepTh       2469.25     1.0     561.6
#  373 │ RANDOM     ca-HepTh       4938.5      0.25     78.4
#  374 │ RANDOM     ca-HepTh       4938.5      0.5    2277.6
#  375 │ RANDOM     ca-HepTh       4938.5      0.75   3958.6
#  376 │ RANDOM     ca-HepTh       4938.5      1.0    1463.9
#  377 │ RANDOM     ca-HepTh       7407.75     0.25     64.4
#  378 │ RANDOM     ca-HepTh       7407.75     0.5    2304.0
#  379 │ RANDOM     ca-HepTh       7407.75     0.75   5806.5
#  380 │ RANDOM     ca-HepTh       7407.75     1.0    3061.4
#  381 │ RANDOM     ca-HepTh       9877.0      0.25   9388.1
#  382 │ RANDOM     ca-HepTh       9877.0      0.5    9466.7
#  383 │ RANDOM     ca-HepTh       9877.0      0.75   9675.3
#  384 │ RANDOM     ca-HepTh       9877.0      1.0    9696.0
#  385 │ RANDOM     email-EU-core   251.25     0.25     92.1
#  386 │ RANDOM     email-EU-core   251.25     0.5     212.3
#  387 │ RANDOM     email-EU-core   251.25     0.75    237.5
#  388 │ RANDOM     email-EU-core   251.25     1.0      45.6
#  389 │ RANDOM     email-EU-core   502.5      0.25    101.7
#  390 │ RANDOM     email-EU-core   502.5      0.5     344.7
#  391 │ RANDOM     email-EU-core   502.5      0.75    468.9
#  392 │ RANDOM     email-EU-core   502.5      1.0      26.3
#  393 │ RANDOM     email-EU-core   753.75     0.25     94.7
#  394 │ RANDOM     email-EU-core   753.75     0.5     349.6
#  395 │ RANDOM     email-EU-core   753.75     0.75    657.6
#  396 │ RANDOM     email-EU-core   753.75     1.0      66.4
#  397 │ RANDOM     email-EU-core  1005.0      0.25    935.6
#  398 │ RANDOM     email-EU-core  1005.0      0.5     943.8
#  399 │ RANDOM     email-EU-core  1005.0      0.75    985.6
#  400 │ RANDOM     email-EU-core  1005.0      1.0     992.4
#  401 │ RANDOM     facebook         83.25     0.25     24.5
#  402 │ RANDOM     facebook         83.25     0.5      59.9
#  403 │ RANDOM     facebook         83.25     0.75     78.4
#  404 │ RANDOM     facebook         83.25     1.0      19.0
#  405 │ RANDOM     facebook        166.5      0.25     26.5
#  406 │ RANDOM     facebook        166.5      0.5      97.0
#  407 │ RANDOM     facebook        166.5      0.75    151.1
#  408 │ RANDOM     facebook        166.5      1.0      24.3
#  409 │ RANDOM     facebook        249.75     0.25     35.0
#  410 │ RANDOM     facebook        249.75     0.5     119.7
#  411 │ RANDOM     facebook        249.75     0.75    205.8
#  412 │ RANDOM     facebook        249.75     1.0      70.5
#  413 │ RANDOM     facebook        333.0      0.25    161.5
#  414 │ RANDOM     facebook        333.0      0.5     214.2
#  415 │ RANDOM     facebook        333.0      0.75    274.4
#  416 │ RANDOM     facebook        333.0      1.0     249.9
#  417 │ RANDOM     karate            8.5      0.25      1.9
#  418 │ RANDOM     karate            8.5      0.5       5.2
#  419 │ RANDOM     karate            8.5      0.75      8.3
#  420 │ RANDOM     karate            8.5      1.0       4.1
#  421 │ RANDOM     karate           17.0      0.25      2.2
#  422 │ RANDOM     karate           17.0      0.5       8.3
#  423 │ RANDOM     karate           17.0      0.75     15.0
#  424 │ RANDOM     karate           17.0      1.0       9.6
#  425 │ RANDOM     karate           25.5      0.25      2.2
#  426 │ RANDOM     karate           25.5      0.5      10.7
#  427 │ RANDOM     karate           25.5      0.75     20.0
#  428 │ RANDOM     karate           25.5      1.0      12.3
#  429 │ RANDOM     karate           34.0      0.25      2.6
#  430 │ RANDOM     karate           34.0      0.5       9.2
#  431 │ RANDOM     karate           34.0      0.75     24.7
#  432 │ RANDOM     karate           34.0      1.0      11.3
#  433 │ RANDOM     p2p            1575.25     0.25    217.3
#  434 │ RANDOM     p2p            1575.25     0.5    1009.7
#  435 │ RANDOM     p2p            1575.25     0.75   1259.9
#  436 │ RANDOM     p2p            1575.25     1.0     143.9
#  437 │ RANDOM     p2p            3150.5      0.25    229.0
#  438 │ RANDOM     p2p            3150.5      0.5    1611.8
#  439 │ RANDOM     p2p            3150.5      0.75   2543.2
#  440 │ RANDOM     p2p            3150.5      1.0     771.7
#  441 │ RANDOM     p2p            4725.75     0.25    225.2
#  442 │ RANDOM     p2p            4725.75     0.5    1616.6
#  443 │ RANDOM     p2p            4725.75     0.75   3741.0
#  444 │ RANDOM     p2p            4725.75     1.0    1582.3
#  445 │ RANDOM     p2p            6301.0      0.25   1971.8
#  446 │ RANDOM     p2p            6301.0      0.5    3479.5
#  447 │ RANDOM     p2p            6301.0      0.75   5780.6
#  448 │ RANDOM     p2p            6301.0      1.0    6018.0
# 7-element Vector{String}:
#  "karate"
#  "ca-GrQc"
#  "ca-HepTh"
#  "CollegeMsg"
#  "email-EU-core"
#  "facebook"
#  "p2p"

# %%
df_temp_MTS = filter(row -> row.Algorithm == "MTS", df_025)
df_temp_algoDegree = filter(row -> row.Algorithm == "DEG", df_025)
df_temp_algoRandom = filter(row -> row.Algorithm == "RANDOM", df_025)
df_temp_algoMaxDegree = filter(row -> row.Algorithm == "MAX DEG", df_025)

x1 = (df_temp_MTS.l, df_temp_MTS.avg)
x2 = (df_temp_algoDegree.l, df_temp_algoDegree.avg)
x3 = (df_temp_algoRandom.l, df_temp_algoRandom.avg)
x4 = (df_temp_algoMaxDegree.l, df_temp_algoMaxDegree.avg)

# plot all series in same figure
plot(x1, label="MTS")
plot!(x2, label="DEG")
plot!(x3, label="RANDOM")
plot!(x4, label="MAX DEG")
# name of the plot
title!("$(graph) th: $(th)")
savefig("$(graph)_$(th).png")

#savefig to path
# Out:
# UndefVarError: df_025 not defined
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ ~/Documents/vscode/SocialNetworks/src/plots/plots.ipynb:1

# %%
all_th = [0.25, 0.5, 0.75, 1.0]

for th in all_th
    for graph in graphs
        df_temp = filter(row -> row.th == th, df)
        df_temp = filter(row -> row.Graph == graph, df_temp)

        df_temp_MTS = filter(row -> row.Algorithm == "MTS", df_temp)
        df_temp_algoDegree = filter(row -> row.Algorithm == "DEG", df_temp)
        df_temp_algoRandom = filter(row -> row.Algorithm == "RANDOM", df_temp)
        df_temp_algoMaxDegree = filter(row -> row.Algorithm == "MAX DEG", df_temp)

        x1 = (df_temp_MTS.l, df_temp_MTS.avg)
        x2 = (df_temp_algoDegree.l, df_temp_algoDegree.avg)
        x3 = (df_temp_algoRandom.l, df_temp_algoRandom.avg)
        x4 = (df_temp_algoMaxDegree.l, df_temp_algoMaxDegree.avg)

        # plot all series in same figure
        plot(x1, label="MTS")
        plot!(x2, label="DEG")
        plot!(x3, label="RANDOM")
        plot!(x4, label="MAX DEG")
        # name of the plot
        title!("$(graph) th: $(th)")
        savefig("$(graph)_$(th).png")
    end
end
